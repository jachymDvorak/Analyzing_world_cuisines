# %% [markdown]
# # LOADING DATA
#
# Data was scraped from BBC Food using Scrapy. The code can be found in the GitHub repo.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw = pd.read_csv('datasets/BBC_recipe_data.csv')
raw.head()
# Out:
#            cook_time  cuisine  \
# 0  30 mins to 1 hour  African
# 1      10 to 30 mins  African
# 2  30 mins to 1 hour  African
# 3  30 mins to 1 hour    Irish
# 4  30 mins to 1 hour   Indian
#
#                                          ingredients  \
# 0  peppers,sweet potatoes,red onions,cherry tomat...
# 1  basmati rice,vegetable oil,chicken thighs,onio...
# 2  ground ginger,garlic,chilli,thyme,cinnamon,nut...
# 3  mashed potato,potatoes,plain flour,milk,butter...
# 4  vegetable oil,onion,sea salt,garlic,cumin,cori...
#
#                                     ingredients_full  \
# 0  2 large red or orange peppers, de-seeded and c...
# 1  300g/10½oz basmati rice,1 tbsp vegetable oil,8...
# 2  30g/1oz ground ginger ,30g/1oz garlic granules...
# 3  250g/9oz colcannon or mashed potato,250g/9oz p...
# 4  1 tbsp vegetable oil,1 large onion, thinly sli...
#
#                                        name          prep_time    rating  \
# 0                Moroccan-style roasted veg  less than 30 mins  3.888889
# 1                 Jollof rice with chicken   less than 30 mins  3.470588
# 2  Jollof Quorn pilau with salted cucumber   less than 30 mins  3.200000
# 3                       Boxty with mackerel  less than 30 mins  5.000000
# 4        Mixed vegetable and almond biryani  less than 30 mins  2.223214
#
#    rating_count  servings
# 0             9  Serves 2
# 1            17  Serves 4
# 2             5  Serves 4
# 3             1  Serves 4
# 4           112  Serves 4

# %%
raw.shape
# Out:
# (1773, 9)

# %%
raw.isna().sum()
# Out:
# cook_time           0
# cuisine             0
# ingredients         0
# ingredients_full    0
# name                0
# prep_time           0
# rating              0
# rating_count        0
# servings            6
# dtype: int64

# %%
raw[raw['servings'].isna()]
# Out:
#               cook_time        cuisine  \
# 138        1 to 2 hours  North African
# 595   30 mins to 1 hour         French
# 770   30 mins to 1 hour        British
# 1051       over 2 hours       Japanese
# 1187  30 mins to 1 hour         Indian
# 1253      10 to 30 mins         Indian
#
#                                             ingredients  \
# 138   vegetable oil,lamb chops,onion,saffron,ground ...
# 595   olive oil,globe artichoke,monkfish,pancetta,sh...
# 770   plain flour,eggs,wholegrain mustard,milk,beef ...
# 1051  soy sauce,mirin,teriyaki sauce,sugar,pork bell...
# 1187  cumin,coriander seeds,fennel seeds,fenugreek,v...
# 1253  yoghurt,rice vinegar,ginger,garlic,chilli powd...
#
#                                        ingredients_full  \
# 138   2 tbsp vegetable oil ,500g/1lb 2oz lamb chops,...
# 595   5 tbsp olive oil,1 fresh globe artichoke, hear...
# 770   225g/8oz plain flour,8 free-range eggs,1 tbsp ...
# 1051  175ml/6fl oz dark soy sauce,120ml/4fl oz sake,...
# 1187  1 tsp cumin seeds,1 tsp coriander seeds,1 tsp ...
# 1253  150g/5½oz Greek yoghurt,2 tbsp rice vinegar,3c...
#
#                                 name          prep_time    rating  \
# 138                      Harira soup  less than 30 mins  2.333333
# 595             Monkfish Bourguignon  less than 30 mins  5.000000
# 770        Classic toad in the hole           overnight  5.000000
# 1051  Chashu (Japanese braised pork)  less than 30 mins  5.000000
# 1187                   Prawn dopiaza  less than 30 mins  5.000000
# 1253            Indian fried chicken       over 2 hours  5.000000
#
#       rating_count servings
# 138              3      NaN
# 595              1      NaN
# 770              3      NaN
# 1051             1      NaN
# 1187             3      NaN
# 1253             3      NaN

# %%
for column in raw.columns:
    print("---- %s ---" % column)
    print(raw[column].value_counts())
# Out:
# ---- cook_time ---
# 10 to 30 mins          643
# 30 mins to 1 hour      492
# 1 to 2 hours           269
# over 2 hours           255
# less than 10 mins      107
# no cooking required      7
# Name: cook_time, dtype: int64
# ---- cuisine ---
# Italian                       357
# British                       354
# Indian                        224
# Thai and South-East Asian     123
# French                        116
# Chinese                       110
# American                       86
# Mexican                        65
# North African                  49
# Turkish and Middle Eastern     45
# Caribbean                      38
# Spanish                        38
# Greek                          32
# East European                  31
# Japanese                       28
# African                        17
# Pakistani                      15
# Nordic                         13
# Korean                         10
# Irish                           9
# Portuguese                      7
# South American                  6
# Name: cuisine, dtype: int64
# ---- ingredients ---
# plantains,black beans,sea salt,black pepper,chilli,herbs,fresh coriander,red onion,plain flour,olive oil,iceberg lettuce,burger,tomato,avocado,chilli sauce                                                 1
# yoghurt,butter,ginger,cumin,coriander,chilli powder,turmeric,limes,tomato purée,garam masala,oil,white pepper,milk,salt,sugar,flour,baking powder,rapeseed oil,butter,nigella seeds,onion,coriander,mint    1
# potatoes,cod,salt,garlic,chilli,chilli,coriander,chilli powder,cumin,ginger,egg,plain flour,vegetable oil                                                                                                   1
# teriyaki sauce,lemongrass,ginger,soba noodles,eggs,pepper,pepper,onion,spring onions,mushrooms,garlic,beansprouts,teriyaki sauce,vegetable oil,sesame seeds                                                 1
# honey,soy sauce,chicken thighs,brown rice,salt,sesame oil,rapeseed oil,bok choi,coconut oil,black sesame seeds,fresh coriander,pumpkin seeds                                                                1
#                                                                                                                                                                                                            ..
# vegetable oil,cumin,chilli,ginger,onions,chilli,pepper,pepper,salt,turmeric,chilli powder,paneer,tomatoes,vinegar,cumin,garam masala                                                                        1
# noodles,noodles,carrot,spring onions,green beans,beansprouts,sunflower oil,garlic,garlic,prawns,soy sauce,honey,ketchup                                                                                     1
# vegetable oil,spring onions,pepper,cumin,smoked paprika,roast chicken,wraps,fresh coriander,lime,soured cream,black pepper                                                                                  1
# vegetable oil,chicken breast,star anise,cinnamon,cardamom,cloves,peppercorns,mace,chilli,ginger,onions,curry leaves,turmeric,black pepper,cinnamon,coconut milk,cherry tomatoes,rice,celery,cress,cress     1
# lemongrass,chillies,ginger,lime,garlic,shallots,cumin,fresh coriander,olive oil,tofu,shallot,vegetable stock,coconut milk,brown sugar,ginger,rice noodles,broccoli,beansprouts,chilli,Thai basil,lime       1
# Name: ingredients, Length: 1773, dtype: int64
# ---- ingredients_full ---
# 400g/14oz pork fillet ,2 tbsp sunflower oil,25g/1oz butter,1 onion, finely sliced,2 tsp paprika,225g/8oz button chestnut mushrooms, halved,140ml/5fl oz carton soured cream,1 tbsp lemon juice,salt and freshly ground black pepper,1 tbsp chopped fresh parsley,mashed potato                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# 500g/1lb 2oz cooked rice (preferably one-day old) or 200g/7oz rice,2 tbsp oil,4 eggs, beaten ,3 tbsp light soy sauce ,½ - 1 tsp chilli flakes, to taste ,1 medium courgette (approximately 200g/7oz), cut into cubes ,150g/5½oz frozen peas ,1 bunch coriander, leaves and stalks separated, leaves roughly chopped, stalks finely chopped ,1 lime, juice of half, half cut into wedges,salt and black pepper                                                                                                                                                                                                                                                                                                                                               1
# 225g/8oz boneless, skinless chicken breasts, cut into thin strips,1 free-range egg white ,2 tsp cornflour,1 tsp salt,½ tsp freshly ground white pepper,225g/8oz fresh thin egg noodles (substitute dried egg noodles if unavailable),300ml/10fl oz groundnut or vegetable oil ,175g/6oz fresh beansprouts,2 tbsp Shaoxing rice wine or dry sherry,2 tbsp oyster sauce,1 tbsp light soy sauce,300ml/10½fl oz chicken stock ,1 tsp salt,½ tsp freshly ground black pepper,1 tbsp cornflour, mixed with 1½ tbsp water,3 tbsp finely chopped spring onions, to garnish                                                                                                                                                                                          1
# 900g/2lb diced stewing beef,25g/1oz flour, seasoned with salt and freshly ground black pepper, plus extra for dusting,100g/3½oz butter,2 onions, roughly chopped,2 cloves garlic, roughly chopped,2 medium carrots, roughly chopped,150g/5½oz button mushrooms,2 sprigs fresh thyme,1 bay leaf,400ml/14fl oz good-quality ale,500ml/17fl oz beef stock,salt and freshly ground black pepper,1 free-range whole egg beaten with 1 free-range egg yolk,300g/10½oz ready-made rolled puff pastry                                                                                                                                                                                                                                                               1
# 2 shallots, thinly sliced,½ tsp sesame oil,1 green finger chilli, finely chopped (optional),2 tbsp Thai green curry paste (seek out a vegetarian version if required),300ml/10fl oz hot vegetable stock,200g/7oz lighter coconut milk,1 tsp Thai fish sauce or light soy sauce,1 medium aubergine, cut into 2cm/1in chunks ,2 kaffir lime leaves,200g/7oz tofu, cut into 1.5cm/½in squares,½ green pepper, cut into thin slices,50g/1¾oz mangetout ,50g/1¾oz baby corn, halved or cut into quarters, depending on size,juice of 1 lime, plus lime wedges to serve,handful finely chopped fresh coriander, to serve,150g/5½oz basmati rice, to serve                                                                                                         1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ..
# 1kg/2lb 3oz neck of lamb (on the bone), preferably Welsh, cut into serving pieces,2 litres/3 pints 10½fl oz lamb stock,225g/8oz potatoes, peeled and roughly chopped,225g/8oz onions, roughly chopped,225g/8oz leeks, trimmed and sliced into 1cm/½in slices,225g/8oz carrots, peeled and roughly chopped,225g/8oz swede, peeled and roughly chopped                                                                                                                                                                                                                                                                                                                                                                                                        1
# 8 chicken thighs, bone in,2–3 tbsp sunflower oil,2½ tsp cumin seeds,2 tsp black mustard seeds,6 garlic cloves, finely chopped,4cm/1½in fresh root ginger, finely grated,3 large onions, roughly chopped ,2–3 tsp ground turmeric,2 tsp freshly chopped green bird’s-eye chillies (or to taste) ,400g tin chopped tomatoes,2 tsp garam masala,salt,fresh coriander, to garnish                                                                                                                                                                                                                                                                                                                                                                               1
# 3 free-range egg yolks,3 tsp Dijon mustard,4 tsp white wine vinegar,500ml/18fl oz vegetable oil,3 free-range eggs, hard boiled and grated,4 banana shallots, finely chopped,75g/2½oz gherkins, chopped ,100g/3½oz capers, drained,50g/1¾oz flatleaf parsley,1 shallot, finely chopped,25g/1oz butter,½ tsp sea salt,400g/14oz frozen peas (defrosted),3 tsp sugar,100ml/3½fl oz chicken stock, boiling hot,10 fresh mint leaves ,8 large potatoes,vegetable oil, for deep frying,salt,2 free-range egg whites,350g/12oz self-raising flour, plus extra for dusting,large pinch bicarbonate of soda,340ml/12fl oz sparkling water (or, if you prefer, beer),1 whole brill (alternatively use turbot or flounder), filleted, skinned and cut into portions    1
# 1 medium baking potato (about 180g/6oz),½ leek, sliced,black pepper,15g/½oz reduced-fat cheddar cheese, grated,15g/½oz cooked bacon or ham, chopped,1 eating apple, roughly chopped,1 x 80g/2¾oz can tuna (in spring water), drained,½ x 198g/7oz can sweetcorn, drained,1 tbsp reduced-fat mayonnaise,black pepper,50g/1¾oz frozen peas,1 x 80g/2¾oz can skinless and boneless salmon,1 tbsp mayonnaise                                                                                                                                                                                                                                                                                                                                                    1
# 4 lean lamb chops or cutlets,1 tbsp, fresh mint,1 tbsp, fresh rosemary,2 cloves garlic,2 tbsp olive oil,1 small aubergine, sliced,1 courgette, sliced,1 red or yellow pepper, cut in large chunks,50g/2oz feta cheese, crumbled,250g/9oz cherry tomatoes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Name: ingredients_full, Length: 1773, dtype: int64
# ---- name ---
# Prawn linguine                                                  2
# Roast turkey crown                                              2
# Vegetable Thai curry                                            2
# Ackee and saltfish                                              2
# Quick fish curry                                                2
#                                                                ..
# Roast beef with Yorkshire puddings, roast potatoes and gravy    1
# Garlic chicken with cucumber                                    1
# Fritto misto with chilli-lime gremolata                         1
# Clams and scallops in a black bean sauce                        1
# Prawn saffron biryani                                           1
# Name: name, Length: 1765, dtype: int64
# ---- prep_time ---
# less than 30 mins    1316
# 30 mins to 1 hour     191
# overnight             107
# 1-2 hours              93
# over 2 hours           66
# Name: prep_time, dtype: int64
# ---- rating ---
# 5.000000    651
# 4.000000    144
# 4.500000     83
# 4.666667     62
# 4.800000     37
#            ...
# 4.736842      1
# 4.363636      1
# 4.894737      1
# 4.368421      1
# 4.680000      1
# Name: rating, Length: 272, dtype: int64
# ---- rating_count ---
# 1      356
# 2      217
# 3      180
# 4      125
# 5      111
#       ...
# 269      1
# 42       1
# 43       1
# 45       1
# 326      1
# Name: rating_count, Length: 82, dtype: int64
# ---- servings ---
# Serves 4                      861
# Serves 2                      224
# Serves 6                      192
# Serves 4-6                    112
# Serves 6-8                     49
#                              ...
# Makes 2 fish cakes              1
# Makes 10-12                     1
# Serves 4 - 5                    1
# Serves 2 or 4 sharing           1
# Makes 2 x 25cm/10in pizzas      1
# Name: servings, Length: 86, dtype: int64

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ### Cleaning serving size to a number

# %%
raw.servings.value_counts()
# Out:
# Serves 4                      861
# Serves 2                      224
# Serves 6                      192
# Serves 4-6                    112
# Serves 6-8                     49
#                              ...
# Makes 2 fish cakes              1
# Makes 10-12                     1
# Serves 4 - 5                    1
# Serves 2 or 4 sharing           1
# Makes 2 x 25cm/10in pizzas      1
# Name: servings, Length: 86, dtype: int64

# %%
servings = raw.servings

servings_c = servings.str.replace(r'[A-Za-z ]', '')
raw.servings = servings_c

# %% [markdown]
# # CUISINE COUNTS

# %%
cuisines_n = raw.cuisine.value_counts()

#set up plot
size = (10,10)
fig, ax = plt.subplots(1, 1, figsize = size)

sns.set_theme(style = "white")
ax = sns.countplot(y = 'cuisine', data = raw, palette="Reds_r", order = raw['cuisine'].value_counts().index) #set order
sns.despine()

# %%
#relative frequencies of cuisines

raw['cuisine'].value_counts(normalize=True) * 100
# Out:
# Italian                       20.135364
# British                       19.966159
# Indian                        12.633954
# Thai and South-East Asian      6.937394
# French                         6.542583
# Chinese                        6.204174
# American                       4.850536
# Mexican                        3.666103
# North African                  2.763677
# Turkish and Middle Eastern     2.538071
# Caribbean                      2.143260
# Spanish                        2.143260
# Greek                          1.804851
# East European                  1.748449
# Japanese                       1.579244
# African                        0.958827
# Pakistani                      0.846024
# Nordic                         0.733221
# Korean                         0.564016
# Irish                          0.507614
# Portuguese                     0.394811
# South American                 0.338409
# Name: cuisine, dtype: float64

# %%
# create table of average ratings (nanmean) and number of ratings for each cuisine
ratings = raw.groupby('cuisine').agg({'rating': [np.nanmean],
                           'rating_count': [np.nansum]})

ratings.columns = ratings.columns.droplevel()
ratings.reset_index(inplace = True)
ratings.columns = ['Cuisine', 'Average Rating', 'Number of ratings']
ratings
# Out:
#                        Cuisine  Average Rating  Number of ratings
# 0                      African        4.454479                 80
# 1                     American        4.648867                908
# 2                      British        4.459277               3629
# 3                    Caribbean        4.578989                188
# 4                      Chinese        4.561886               1008
# 5                East European        4.720223                267
# 6                       French        4.563308                791
# 7                        Greek        4.508476                536
# 8                       Indian        4.434341               2840
# 9                        Irish        4.437608                 56
# 10                     Italian        4.549872               3863
# 11                    Japanese        4.474355                295
# 12                      Korean        4.745201                 59
# 13                     Mexican        4.573636                780
# 14                      Nordic        4.730769                 50
# 15               North African        4.548909                433
# 16                   Pakistani        4.413148                 85
# 17                  Portuguese        4.673160                 46
# 18              South American        4.952381                 16
# 19                     Spanish        4.671221                336
# 20   Thai and South-East Asian        4.491960                905
# 21  Turkish and Middle Eastern        4.597897                498

# %%
size = (17,10)
fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize = size)

#plot number of ratings 
axs[0] = sns.barplot(y= 'Cuisine', x = 'Number of ratings', data = ratings, 
            order = ratings.sort_values('Number of ratings', ascending = False)['Cuisine'],
            palette = 'viridis',
            ax = axs[0])

#plot average ratings per cuisine
axs[1] = sns.barplot(y= 'Cuisine', x = 'Average Rating', data = ratings, 
            order = ratings.sort_values('Average Rating', ascending = False)['Cuisine'],
            palette = 'viridis',
            ax = axs[1])
sns.despine()
plt.tight_layout()

# %%
# does the average number of ratings and ratings correlate?
ratings.corr()
# Out:
#                    Average Rating  Number of ratings
# Average Rating           1.000000          -0.341062
# Number of ratings       -0.341062           1.000000

# %% [markdown]
# It looks like the more ratings a cuisine has, the lower rating it has (0.3 corr). That is expected due to regression to the mean and higher chances of extremities at lower sample size.

# %% [markdown]
# Interestingly, prep time and cook time do not correlate at all.

# %%
raw[['prep_time', 'cook_time']].apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)
# Out:
#            prep_time  cook_time
# prep_time   1.000000  -0.012224
# cook_time  -0.012224   1.000000

# %%
df1 = raw[['cuisine', 'cook_time', 'prep_time']]
cook_t = pd.pivot_table(df1, columns = ['cuisine'], index = ['cook_time'], aggfunc = 'count').T

# %%
cuisines_above_threshold = raw.cuisine.value_counts()[raw.cuisine.value_counts() > 20].index

# %%
raw = raw[raw['cuisine'].isin(cuisines_above_threshold)]

# %%
df1 = raw[['cuisine', 'cook_time']]
cook_t = pd.pivot(df1, columns = ['cuisine'], values=  ['cook_time'])
cook_t
# Out:
#         cook_time                                               \
# cuisine  American British     Caribbean Chinese  East European
# 4             NaN     NaN           NaN     NaN            NaN
# 5             NaN     NaN           NaN     NaN            NaN
# 6             NaN     NaN  over 2 hours     NaN            NaN
# 9             NaN     NaN  over 2 hours     NaN            NaN
# 10            NaN     NaN           NaN     NaN            NaN
# ...           ...     ...           ...     ...            ...
# 1742          NaN     NaN           NaN     NaN   1 to 2 hours
# 1743          NaN     NaN           NaN     NaN  10 to 30 mins
# 1745          NaN     NaN           NaN     NaN   over 2 hours
# 1746          NaN     NaN           NaN     NaN            NaN
# 1747          NaN     NaN           NaN     NaN   1 to 2 hours
#
#                                                                           \
# cuisine             French              Greek             Indian Italian
# 4                      NaN                NaN  30 mins to 1 hour     NaN
# 5                      NaN                NaN       1 to 2 hours     NaN
# 6                      NaN                NaN                NaN     NaN
# 9                      NaN                NaN                NaN     NaN
# 10       30 mins to 1 hour                NaN                NaN     NaN
# ...                    ...                ...                ...     ...
# 1742                   NaN                NaN                NaN     NaN
# 1743                   NaN                NaN                NaN     NaN
# 1745                   NaN                NaN                NaN     NaN
# 1746                   NaN  30 mins to 1 hour                NaN     NaN
# 1747                   NaN                NaN                NaN     NaN
#
#                                                                           \
# cuisine Japanese Mexican North African Spanish Thai and South-East Asian
# 4            NaN     NaN           NaN     NaN                       NaN
# 5            NaN     NaN           NaN     NaN                       NaN
# 6            NaN     NaN           NaN     NaN                       NaN
# 9            NaN     NaN           NaN     NaN                       NaN
# 10           NaN     NaN           NaN     NaN                       NaN
# ...          ...     ...           ...     ...                       ...
# 1742         NaN     NaN           NaN     NaN                       NaN
# 1743         NaN     NaN           NaN     NaN                       NaN
# 1745         NaN     NaN           NaN     NaN                       NaN
# 1746         NaN     NaN           NaN     NaN                       NaN
# 1747         NaN     NaN           NaN     NaN                       NaN
#
#
# cuisine Turkish and Middle Eastern
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 9                              NaN
# 10                             NaN
# ...                            ...
# 1742                           NaN
# 1743                           NaN
# 1745                           NaN
# 1746                           NaN
# 1747                           NaN
#
# [1696 rows x 15 columns]

# %%
df1 = raw[['cuisine', 'cook_time', 'prep_time']]
cook_t = pd.pivot_table(df1, index = ['cuisine'], columns = ['cook_time'], aggfunc = 'count')
cook_t
# Out:
#                               prep_time                                  \
# cook_time                  1 to 2 hours 10 to 30 mins 30 mins to 1 hour
# cuisine
# American                           11.0          22.0              27.0
# British                            95.0          54.0              97.0
# Caribbean                           4.0          13.0              18.0
# Chinese                             5.0          53.0              13.0
# East European                       6.0          10.0               9.0
# French                             19.0          35.0              34.0
# Greek                               3.0          10.0              15.0
# Indian                             29.0          89.0              85.0
# Italian                            45.0         172.0              84.0
# Japanese                            1.0          12.0               6.0
# Mexican                             8.0          27.0              19.0
# North African                      13.0          10.0              12.0
# Spanish                             4.0          17.0              15.0
# Thai and South-East Asian           3.0          80.0              15.0
# Turkish and Middle Eastern          8.0          18.0              12.0
#
#
# cook_time                  less than 10 mins no cooking required over 2 hours
# cuisine
# American                                 5.0                 2.0         19.0
# British                                  5.0                 NaN        103.0
# Caribbean                                NaN                 NaN          3.0
# Chinese                                 33.0                 NaN          6.0
# East European                            NaN                 NaN          6.0
# French                                   4.0                 NaN         24.0
# Greek                                    1.0                 NaN          3.0
# Indian                                   6.0                 NaN         15.0
# Italian                                 26.0                 3.0         27.0
# Japanese                                 6.0                 1.0          2.0
# Mexican                                  2.0                 1.0          8.0
# North African                            2.0                 NaN         12.0
# Spanish                                  NaN                 NaN          2.0
# Thai and South-East Asian               13.0                 NaN         12.0
# Turkish and Middle Eastern               2.0                 NaN          5.0

# %%
df1 = raw[['cuisine', 'cook_time', 'prep_time']]
cook_t = pd.pivot_table(df1, index = ['cuisine'], columns = ['prep_time'], aggfunc = 'count')
cook_t
# Out:
#                            cook_time                                      \
# prep_time                  1-2 hours 30 mins to 1 hour less than 30 mins
# cuisine
# American                         3.0               6.0              60.0
# British                         22.0              51.0             253.0
# Caribbean                        5.0               6.0              16.0
# Chinese                          4.0               8.0              90.0
# East European                    3.0               3.0              24.0
# French                           3.0              14.0              87.0
# Greek                            4.0               1.0              25.0
# Indian                          15.0              30.0             150.0
# Italian                         18.0              40.0             281.0
# Japanese                         1.0               2.0              22.0
# Mexican                          2.0               2.0              57.0
# North African                    2.0               2.0              41.0
# Spanish                          1.0               2.0              32.0
# Thai and South-East Asian        5.0               7.0              98.0
# Turkish and Middle Eastern       1.0               8.0              26.0
#
#
# prep_time                  over 2 hours overnight
# cuisine
# American                            5.0      12.0
# British                            11.0      17.0
# Caribbean                           3.0       8.0
# Chinese                             2.0       6.0
# East European                       1.0       NaN
# French                              5.0       7.0
# Greek                               NaN       2.0
# Indian                             11.0      18.0
# Italian                             7.0      11.0
# Japanese                            1.0       2.0
# Mexican                             3.0       1.0
# North African                       NaN       4.0
# Spanish                             1.0       2.0
# Thai and South-East Asian           8.0       5.0
# Turkish and Middle Eastern          5.0       5.0

# %% [markdown]
# # WORDS

# %%
from sklearn.preprocessing import MultiLabelBinarizer

#create instance
mlb = MultiLabelBinarizer()

#create a Bag of Words (each word has its own column and is binary - 0 or 1)

#split ingredients by ','
ingredients = raw['ingredients'].str.split(',')

#convert all ingredients to lowercase
ingredients = pd.Series([[x.lower() for x in sublst] for sublst in ingredients])

#create a dataframe of binarized ingredient columns
ing_list = pd.DataFrame(mlb.fit_transform(ingredients), 
                        columns = mlb.classes_, index = ingredients.index)

# %%
# create new dataframe
df = raw.copy()

# drop useless column = name
df.drop(columns = ['ingredients_full', 'name'], inplace = True)
df.head()
# Out:
#             cook_time    cuisine  \
# 4   30 mins to 1 hour     Indian
# 5        1 to 2 hours     Indian
# 6        over 2 hours  Caribbean
# 9        over 2 hours  Caribbean
# 10  30 mins to 1 hour     French
#
#                                           ingredients          prep_time  \
# 4   vegetable oil,onion,sea salt,garlic,cumin,cori...  less than 30 mins
# 5   curry leaves,onions,rapeseed oil,yoghurt,tomat...  30 mins to 1 hour
# 6   mutton,lemon,coriander,black pepper,garlic,oni...          overnight
# 9   onions,garlic,chives,white wine vinegar,cloves...  less than 30 mins
# 10  buckwheat flour,egg,butter,ghee,olive oil,blac...          1-2 hours
#
#       rating  rating_count servings
# 4   2.223214           112        4
# 5   4.000000             1        6
# 6   4.500000             2      4-6
# 9   4.000000             2        6
# 10  5.000000             1        4

# %%
# add cuisine to ingredient list
ing_list['cuisine'] = df['cuisine']

# %%
# create relative frequencies of cuisines
frequencies_cuisines = pd.DataFrame(raw['cuisine'].value_counts(normalize=True) * 100)

# name column
frequencies_cuisines.columns = ['relative_count']

# create column of absolute frequencies
frequencies_cuisines['absolute_count'] = raw['cuisine'].value_counts()

# view
frequencies_cuisines
# Out:
#                             relative_count  absolute_count
# Italian                          21.049528             357
# British                          20.872642             354
# Indian                           13.207547             224
# Thai and South-East Asian         7.252358             123
# French                            6.839623             116
# Chinese                           6.485849             110
# American                          5.070755              86
# Mexican                           3.832547              65
# North African                     2.889151              49
# Turkish and Middle Eastern        2.653302              45
# Caribbean                         2.240566              38
# Spanish                           2.240566              38
# Greek                             1.886792              32
# East European                     1.827830              31
# Japanese                          1.650943              28

# %%
# sum counts of each ingredient per cuisine (first group by cuisine, then apply sum per COLUMN, and then drop useless col.)
df = ing_list.groupby('cuisine').apply(sum, 0).drop(columns = ['cuisine'])

# merge all binarized ingredients with frequencies
df = df.merge(frequencies_cuisines, how = 'inner', right_index = True, left_index = True)

# view that it worked!
df.head()
# Out:
#                'nduja  00 flour  acidulated water  ackee  ajwain  ale  \
# American            0         0                 0      0       0    0
# British             0         0                 1      1       0    7
# Caribbean           0         0                 0      0       0    0
# Chinese             0         0                 0      0       0    2
# East European       0         0                 0      0       0    0
#
#                aleppo pepper  allspice  almond  almond milk  ...  wine  \
# American                   0         1       0            0  ...     0
# British                    1         5       0            0  ...     2
# Caribbean                  0         0       0            0  ...     0
# Chinese                    0         3       0            1  ...     0
# East European              0         0       0            0  ...     0
#
#                wood pigeon  worcestershire sauce  wraps  yeast  yeast extract  \
# American                 0                    11      0      1              2
# British                  1                    32      0      4              6
# Caribbean                0                     0      3      0              0
# Chinese                  0                     5      0      2              0
# East European            0                     0      0      0              0
#
#                yoghurt  zest  relative_count  absolute_count
# American             1     1        5.070755              86
# British             15     3       20.872642             354
# Caribbean            3     0        2.240566              38
# Chinese              2     1        6.485849             110
# East European        1     0        1.827830              31
#
# [5 rows x 834 columns]

# %%
len(df.index)
# Out:
# 15

# %% [markdown]
# ## Adding plurals together

# %%
import nltk
nltk.edit_distance("onions", "onion")
# Out:
# 1

# %%
ings = list(df.columns)

type(ings)
# Out:
# list

# %%
import itertools

# get all possible combinations
ings_combinations = list(itertools.combinations(ings, 2))

# %%
#get all Levenshtein distances into once dict

distances = {}
for index, pair in enumerate(ings_combinations):
    distances[pair] = nltk.edit_distance(pair[0], pair[1])
    if index % 10000 == 0:
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000

# %%
#sort dictionary

distances_s = sorted(distances.items(), key=lambda x: x[1])

# %%
# get pairs with distance 1 (one letter difference, i.e. "s"/plural)

pairs = []
for entry in distances_s:
    if entry[1] == 1:
        pairs.append(entry[0])

# %%
# print all pairs
for index, pair in enumerate(pairs):
    print(index, pair)
# Out:
# 0 ('ale', 'kale')
# 1 ('almond', 'almonds')
# 2 ('apple', 'apples')
# 3 ('artichoke', 'artichokes')
# 4 ('aubergine', 'aubergines')
# 5 ('avocado', 'avocados')
# 6 ('baguette', 'baguettes')
# 7 ('beef', 'beer')
# 8 ('beetroot', 'beetroots')
# 9 ('black bean', 'black beans')
# 10 ('braising steak', 'braising steaks')
# 11 ('bramley apple', 'bramley apples')
# 12 ('cardamom', 'cardamoms')
# 13 ('carrot', 'carrots')
# 14 ('cashew', 'cashews')
# 15 ('cherry', 'sherry')
# 16 ('chicken', 'chickens')
# 17 ('chicken breast', 'chicken breasts')
# 18 ('chicken liver', 'chicken livers')
# 19 ('chicken thigh', 'chicken thighs')
# 20 ('chickpea', 'chickpeas')
# 21 ('chilli', 'chillis')
# 22 ('chillies', 'chillis')
# 23 ('chipotle', 'chipotles')
# 24 ('chump', 'chumps')
# 25 ('ciabatta', 'ciabattas')
# 26 ('courgette', 'courgettes')
# 27 ('cucumber', 'cucumbers')
# 28 ('egg', 'eggs')
# 29 ('egg white', 'egg whites')
# 30 ('egg yolk', 'egg yolks')
# 31 ('flour tortilla', 'flour tortillas')
# 32 ('gherkin', 'gherkins')
# 33 ('grapeseed oil', 'rapeseed oil')
# 34 ('ham', 'jam')
# 35 ('jerusalem artichoke', 'jerusalem artichokes')
# 36 ('king edward', 'king edwards')
# 37 ('lamb fillet', 'lamb fillets')
# 38 ('leek', 'leeks')
# 39 ('lemon', 'lemons')
# 40 ('lettuce', 'lettuces')
# 41 ('lime', 'limes')
# 42 ('little gem lettuce', 'little gem lettuces')
# 43 ('mince', 'minced')
# 44 ('mushroom', 'mushrooms')
# 45 ('naan bread', 'naan breads')
# 46 ('olive', 'olives')
# 47 ('onion', 'onions')
# 48 ('orange', 'oranges')
# 49 ('oyster', 'oysters')
# 50 ('parsnip', 'parsnips')
# 51 ('partridge', 'partridges')
# 52 ('pear', 'pears')
# 53 ('pear', 'peas')
# 54 ('pears', 'peas')
# 55 ('pecan', 'pecans')
# 56 ('pepper', 'peppers')
# 57 ('pheasant', 'pheasants')
# 58 ('pistachio', 'pistachios')
# 59 ('pitta bread', 'pitta breads')
# 60 ('plantain', 'plantains')
# 61 ('plum', 'plums')
# 62 ('pollack', 'pollock')
# 63 ('pomegranate', 'pomegranates')
# 64 ('pork', 'port')
# 65 ('pork fillet', 'pork fillets')
# 66 ('poussin', 'poussins')
# 67 ('prawn', 'prawns')
# 68 ('rabbit', 'rabbits')
# 69 ('red onion', 'red onions')
# 70 ('rum', 'rump')
# 71 ('sausage', 'sausages')
# 72 ('shallot', 'shallots')
# 73 ('sichuan peppercorn', 'sichuan peppercorns')
# 74 ('spring onion', 'spring onions')
# 75 ('steak', 'steaks')
# 76 ('turnip', 'turnips')
# 77 ('walnut', 'walnuts')

# %%
#manually remove incorrectly labeles plurals
not_plural_indexes = [0, 7, 15, 21, 22, 33, 34, 43, 53, 54, 62, 64, 70]

pairs = [i for j, i in enumerate(pairs) if j not in not_plural_indexes]

# %%
# for each pair, add the columns, remove old ones and create final one (singular)

df_checkpoint = df.copy()

for pair in pairs:
    new_col = df_checkpoint[pair[0]].add(df_checkpoint[pair[1]])
    df_checkpoint.drop(columns = [str(pair[0]), str(pair[1])], inplace = True)
    df_checkpoint[str(pair[0])] = new_col

# %%
# manually remove a "triple" ingredient 

new_col = df['chillis'].add(df['chilli']).add(df['chillies'])
df.drop(columns = ['chillis', 'chilli', 'chillies'], inplace = True)
df['chilli'] = new_col

# %%
from matplotlib.ticker import FuncFormatter

# instantiate dictionary (empty)
ingredients_dict = {}

# set figure size
figsize = (17,17)

# instantiate subplots - 3x5 grid (15 cuisines)
fig, axs = plt.subplots(ncols = 3, nrows = int(len(df.index)/3), figsize = figsize)
axs = axs.flatten()

# for loop enumerated index (index = name of cuisine, enumerate assigns number to each)
for numb, cuisine in enumerate(df.index):
    
    # drop two last columns (absolute and relative frequencies)
    df_plot = df.drop(columns = ['absolute_count', 'relative_count'])
    
    # sort ingredient frequencies and use only top 20 most used
    ings = df_plot.loc[cuisine].sort_values(ascending = False)[:15]
    
    # add to dictionary - key is cuisine, value is list of frequencies of ingredients
    ingredients_dict[cuisine] = ings
    
    # convert to relative from absolute - divide each frequency by total number of recipes from each cuisine
    ing_freq = [ingredient/len(raw[raw['cuisine'] == cuisine]) for ingredient in ingredients_dict[cuisine]]
    
    # add plot to an axis
    axs[numb] = sns.barplot(y = ingredients_dict[cuisine].index, # names of ingredients as index
                            x = ing_freq, # x as frequencies
                            ax = axs[numb], # put to wanted ax (row)
                            palette = "crest") # color
    axs[numb].set_title(cuisine, fontsize = 25) # set title as cuisine
    sns.despine() 
    axs[numb].grid(axis = 'x', linestyle = ':', linewidth = 1.5) # add grid
    axs[numb].xaxis.set_major_formatter(FuncFormatter(lambda x, _: '{:.0%}'.format(x))) # convert x axis ticks format to %
    plt.tight_layout()
    
    # set font size larger to be more readable
    axs[numb].set_yticklabels(labels = ingredients_dict[cuisine].index, size = 14)
    
plt.savefig('cuisine_plots.jpg')
